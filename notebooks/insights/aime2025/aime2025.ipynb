# %%
from modelscope.msdatasets import MsDataset
ds =  MsDataset.load('opencompass/AIME2025', subset_name='AIME2025-I', split='test')
# Out:
# Downloading [README.md]: 100%|██████████| 448/448 [00:00<00:00, 1.52MB/s]
# 2025-12-08 20:53:00,130 - modelscope - INFO - storing https://www.modelscope.cn/api/v1/datasets/opencompass/AIME2025/repo?Source=SDK&Revision=master&FilePath=README.md&View=False in cache at /home/yexuming/.cache/modelscope/hub/datasets/ba6059f1225799b940ee701e1e98792edced48fac85088dfb269b6e16df37489
# 2025-12-08 20:53:00,132 - modelscope - INFO - creating metadata file for /home/yexuming/.cache/modelscope/hub/datasets/ba6059f1225799b940ee701e1e98792edced48fac85088dfb269b6e16df37489
# Downloading data: 100%|██████████| 5.76k/5.76k [00:00<00:00, 9.88MB/s]
# 2025-12-08 20:59:46,168 - modelscope - INFO - storing https://www.modelscope.cn/api/v1/datasets/opencompass/AIME2025/repo?Source=SDK&Revision=master&FilePath=aime2025-I.jsonl in cache at /home/yexuming/.cache/modelscope/hub/datasets/downloads/39dce39ef6acce70838c6ff1978951f2b63fa6e390be807a0f5514ba26985238
# 2025-12-08 20:59:46,170 - modelscope - INFO - creating metadata file for /home/yexuming/.cache/modelscope/hub/datasets/downloads/39dce39ef6acce70838c6ff1978951f2b63fa6e390be807a0f5514ba26985238
# Generating test split: 15 examples [00:00, 2373.69 examples/s]

# %%
ds
# Out:
# Dataset({
#     features: ['question', 'answer'],
#     num_rows: 15
# })
